# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def convertColumnToInt(df):
  for x in df.keys():
    df[x]=df[x].astype(int)

# %%
heart_disease_df = pd.read_csv("/content/HEART_DISEASE_DF.csv")
heart_disease_df
# Out:
#      age  sex restingbp chol blood_sugar max_hr  diagnosis
# 0     63    1       145  233           1    150          0
# 1     67    1       160  286           0    108          2
# 2     67    1       120  229           0    129          1
# 3     37    1       130  250           0    187          0
# 4     41    0       130  204           0    172          0
# ..   ...  ...       ...  ...         ...    ...        ...
# 915   54    0       127  333           1    154          1
# 916   62    1         -  139           0      -          0
# 917   55    1       122  223           1    100          2
# 918   58    1         -  385           1      -          0
# 919   62    1       120  254           0     93          1
#
# [920 rows x 7 columns]

# %%
no_missing_values = heart_disease_df[(heart_disease_df['max_hr']!='-') & (heart_disease_df['restingbp']!='-') &(heart_disease_df['chol']!='-')&(heart_disease_df['blood_sugar']!='-')]
no_missing_values.describe()
# Out:
#               age         sex   diagnosis
# count  745.000000  745.000000  745.000000
# mean    53.130201    0.766443    0.924832
# std      9.392743    0.423378    1.128677
# min     28.000000    0.000000    0.000000
# 25%     46.000000    1.000000    0.000000
# 50%     54.000000    1.000000    1.000000
# 75%     60.000000    1.000000    1.000000
# max     77.000000    1.000000    4.000000

# %%
num = 0
count = 0
for x in no_missing_values.blood_sugar :
  if x =="1.0" or x =='1':
    num+=1
  else:
    num+=0
  count+=1

print(f'The average blood sugar is: {num/count}')
# Out:
# The average blood sugar is: 0.15302013422818792

# %%
sugar_age_plot = sns.violinplot(data=heart_disease_df[heart_disease_df['blood_sugar']!='-'],x='age',hue='blood_sugar',palette='magma').set_title('Age Distribution Separated by Blood Sugar Levels');

# %%
diagnosis_age_plot = sns.violinplot(data=no_missing_values,x='age',hue='diagnosis',palette='crest').set_title('Age Distribution Separated by Heart Disease Diagnosis');

# %%
palette_color = sns.color_palette('crest')
outward_piece = [0.05, 0, 0, 0, 0]
plt.title('Percentage of Heart Disease in the Population')
plt.pie(no_missing_values.diagnosis.value_counts(),labels=no_missing_values.diagnosis.unique(), colors=palette_color, autopct='%.0f%%',explode=outward_piece)
plt.show();

# %%
no_heart_disease_data = no_missing_values[no_missing_values['diagnosis']==0]

# %%
heart_disease_data = no_missing_values[no_missing_values['diagnosis']!=0]

# %%
convertColumnToInt(no_missing_values)
convertColumnToInt(no_heart_disease_data)
convertColumnToInt(heart_disease_data)

# %%
no_heart_disease_data.describe()
# Out:
#               age         sex   restingbp        chol  blood_sugar  \
# count  359.000000  359.000000  359.000000  359.000000   359.000000
# mean    50.323120    0.635097  129.885794  233.119777     0.108635
# std      9.395785    0.482075   16.607052   66.489001     0.311615
# min     28.000000    0.000000   94.000000    0.000000     0.000000
# 25%     43.000000    0.000000  120.000000  201.500000     0.000000
# 50%     51.000000    1.000000  130.000000  230.000000     0.000000
# 75%     57.000000    1.000000  140.000000  268.500000     0.000000
# max     76.000000    1.000000  190.000000  564.000000     1.000000
#
#            max_hr  diagnosis
# count  359.000000      359.0
# mean   149.406685        0.0
# std     23.640028        0.0
# min     69.000000        0.0
# 25%    135.500000        0.0
# 50%    152.000000        0.0
# 75%    168.000000        0.0
# max    202.000000        0.0

# %%
heart_disease_data.describe()
# Out:
#               age         sex   restingbp        chol  blood_sugar  \
# count  386.000000  386.000000  386.000000  386.000000   386.000000
# mean    55.740933    0.888601  135.455959  207.650259     0.194301
# std      8.615012    0.315034   19.927254  112.013448     0.396175
# min     31.000000    0.000000    0.000000    0.000000     0.000000
# 25%     50.000000    1.000000  120.000000  185.250000     0.000000
# 50%     57.000000    1.000000  132.000000  231.000000     0.000000
# 75%     62.000000    1.000000  149.500000  274.000000     0.000000
# max     77.000000    1.000000  200.000000  603.000000     1.000000
#
#            max_hr   diagnosis
# count  386.000000  386.000000
# mean   128.968912    1.784974
# std     23.821175    0.960456
# min     60.000000    1.000000
# 25%    112.000000    1.000000
# 50%    129.000000    1.000000
# 75%    146.000000    3.000000
# max    195.000000    4.000000

# %%
no_missing_values.describe()
# Out:
#               age         sex   restingbp        chol  blood_sugar  \
# count  745.000000  745.000000  745.000000  745.000000   745.000000
# mean    53.130201    0.766443  132.771812  219.923490     0.153020
# std      9.392743    0.423378   18.599746   93.713004     0.360249
# min     28.000000    0.000000    0.000000    0.000000     0.000000
# 25%     46.000000    1.000000  120.000000  197.000000     0.000000
# 50%     54.000000    1.000000  130.000000  231.000000     0.000000
# 75%     60.000000    1.000000  140.000000  271.000000     0.000000
# max     77.000000    1.000000  200.000000  603.000000     1.000000
#
#            max_hr   diagnosis
# count  745.000000  745.000000
# mean   138.817450    0.924832
# std     25.825905    1.128677
# min     60.000000    0.000000
# 25%    120.000000    0.000000
# 50%    140.000000    1.000000
# 75%    160.000000    1.000000
# max    202.000000    4.000000

# %%
palette_color = sns.color_palette('crest')
outward_piece = [0, 0.05, 0, 0]
plt.title('Percentage of Different Diagnosis')
plt.pie(heart_disease_data.diagnosis.value_counts(),labels=heart_disease_data.diagnosis.unique(), colors=palette_color, autopct='%.0f%%',explode=outward_piece)
plt.show();

# %%
sns.kdeplot(
    data=no_missing_values, x="age", y="chol", hue="diagnosis", fill=True, palette = 'crest',
).set_title('Density Plot of Age vs Cholesterol Separated by Diagnosis');

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.title('3D Scatter of Heart Disease Features')
colors = np.where(no_missing_values.diagnosis > 0, "blue", "cornflowerblue")
ax.scatter(no_missing_values.chol, no_missing_values.max_hr,no_missing_values.age,c=colors)
ax.set_zlabel('Age')
ax.set_xlabel('Cholesterol')
ax.set_ylabel('Max HR')
ax.dist = 13
plt.show()
# Out:
# <ipython-input-113-460e3a33d492>:9: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 13
